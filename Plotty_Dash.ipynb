# %%
# !pip install pandas dash
# Out:
# Requirement already satisfied: pandas in c:\users\anyat\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: dash in c:\users\anyat\anaconda3\lib\site-packages (1.21.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\anyat\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: future in c:\users\anyat\anaconda3\lib\site-packages (from dash) (0.18.2)
# Requirement already satisfied: dash-table==4.12.0 in c:\users\anyat\anaconda3\lib\site-packages (from dash) (4.12.0)
# Requirement already satisfied: flask-compress in c:\users\anyat\anaconda3\lib\site-packages (from dash) (1.10.1)
# Requirement already satisfied: plotly in c:\users\anyat\anaconda3\lib\site-packages (from dash) (5.2.1)
# Requirement already satisfied: dash-core-components==1.17.1 in c:\users\anyat\anaconda3\lib\site-packages (from dash) (1.17.1)
# Requirement already satisfied: dash-html-components==1.1.4 in c:\users\anyat\anaconda3\lib\site-packages (from dash) (1.1.4)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\anyat\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\anyat\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\anyat\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\anyat\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\anyat\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (1.1.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anyat\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anyat\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\anyat\anaconda3\lib\site-packages (from pandas) (1.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\anyat\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: brotli in c:\users\anyat\anaconda3\lib\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\anyat\anaconda3\lib\site-packages (from plotly->dash) (8.0.1)

# %%
import wget
import dash
import pandas as pd
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px
import plotly.graph_objects as go

# %%
wget.download("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
wget.download("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/spacex_dash_app.py")
# Out:
# 100% [................................................................................] 2110 / 2110
# 'spacex_dash_app.py'

# %%
spacex_df = pd.read_csv("spacex_launch_dash.csv")
spacex_df
# Out:
#     Unnamed: 0  Flight Number   Launch Site  \
# 0            0              1   CCAFS LC-40
# 1            1              2   CCAFS LC-40
# 2            2              3   CCAFS LC-40
# 3            3              4   CCAFS LC-40
# 4            4              5   CCAFS LC-40
# 5            5              7   CCAFS LC-40
# 6            6              8   CCAFS LC-40
# 7            7              9   CCAFS LC-40
# 8            8             10   CCAFS LC-40
# 9            9             11   CCAFS LC-40
# 10          10             12   CCAFS LC-40
# 11          11             13   CCAFS LC-40
# 12          12             14   CCAFS LC-40
# 13          13             15   CCAFS LC-40
# 14          14             16   CCAFS LC-40
# 15          15             17   CCAFS LC-40
# 16          16             18   CCAFS LC-40
# 17          17             19   CCAFS LC-40
# 18          18             20   CCAFS LC-40
# 19          19             22   CCAFS LC-40
# 20          20             23   CCAFS LC-40
# 21          21             24   CCAFS LC-40
# 22          22             25   CCAFS LC-40
# 23          23             26   CCAFS LC-40
# 24          24             27   CCAFS LC-40
# 25          25             28   CCAFS LC-40
# 26          26              6   VAFB SLC-4E
# 27          27             21   VAFB SLC-4E
# 28          28             29   VAFB SLC-4E
# 29          29             37   VAFB SLC-4E
# 30          30             40   VAFB SLC-4E
# 31          31             42   VAFB SLC-4E
# 32          32             46   VAFB SLC-4E
# 33          33             49   VAFB SLC-4E
# 34          34             51   VAFB SLC-4E
# 35          35             55   VAFB SLC-4E
# 36          36             30    KSC LC-39A
# 37          37             31    KSC LC-39A
# 38          38             32    KSC LC-39A
# 39          39             33    KSC LC-39A
# 40          40             34    KSC LC-39A
# 41          41             35    KSC LC-39A
# 42          42             36    KSC LC-39A
# 43          43             38    KSC LC-39A
# 44          44             39    KSC LC-39A
# 45          45             41    KSC LC-39A
# 46          46             43    KSC LC-39A
# 47          47             44    KSC LC-39A
# 48          48             54    KSC LC-39A
# 49          49             45  CCAFS SLC-40
# 50          50             47  CCAFS SLC-40
# 51          51             48  CCAFS SLC-40
# 52          52             50  CCAFS SLC-40
# 53          53             52  CCAFS SLC-40
# 54          54             53  CCAFS SLC-40
# 55          55             56  CCAFS SLC-40
#
#                       Mission Outcome  class  Payload Mass (kg)  \
# 0                             Success      0               0.00
# 1                             Success      0               0.00
# 2                             Success      0             525.00
# 3                             Success      0             500.00
# 4                             Success      0             677.00
# 5                             Success      0            3170.00
# 6                             Success      0            3325.00
# 7                             Success      0            2296.00
# 8                             Success      0            1316.00
# 9                             Success      0            4535.00
# 10                            Success      0            4428.00
# 11                            Success      0            2216.00
# 12                            Success      0            2395.00
# 13                            Success      0             570.00
# 14                            Success      0            4159.00
# 15                            Success      0            1898.00
# 16                            Success      0            4707.00
# 17               Failure  (in flight)      1            1952.00
# 18                            Success      1            2034.00
# 19                            Success      0            5271.00
# 20                            Success      1            3136.00
# 21                            Success      1            4696.00
# 22                            Success      1            3100.00
# 23                            Success      0            3600.00
# 24                            Success      1            2257.00
# 25                            Success      1            4600.00
# 26                            Success      0             500.00
# 27                            Success      0             553.00
# 28                            Success      1            9600.00
# 29                            Success      1            9600.00
# 30                            Success      1             475.00
# 31                            Success      1            9600.00
# 32                            Success      0            9600.00
# 33                            Success      0            2150.00
# 34                            Success      0            9600.00
# 35                            Success      0            6460.00
# 36                            Success      1            2490.00
# 37                            Success      0            5600.00
# 38                            Success      1            5300.00
# 39                            Success      1            3696.65
# 40                            Success      0            6070.00
# 41                            Success      1            2708.00
# 42                            Success      1            3669.00
# 43                            Success      0            6761.00
# 44                            Success      1            3310.00
# 45                            Success      1            4990.00
# 46                            Success      1            5200.00
# 47                            Success      1            3500.00
# 48                            Success      1            3600.00
# 49                            Success      1            2205.00
# 50  Success  (payload status unclear)      1            3696.65
# 51                            Success      0            4230.00
# 52                            Success      0            6092.00
# 53                            Success      0            2647.00
# 54                            Success      1             362.00
# 55                            Success      0            5384.00
#
#    Booster Version Booster Version Category
# 0   F9 v1.0  B0003                     v1.0
# 1   F9 v1.0  B0004                     v1.0
# 2   F9 v1.0  B0005                     v1.0
# 3   F9 v1.0  B0006                     v1.0
# 4   F9 v1.0  B0007                     v1.0
# 5          F9 v1.1                     v1.1
# 6          F9 v1.1                     v1.1
# 7          F9 v1.1                     v1.1
# 8          F9 v1.1                     v1.1
# 9          F9 v1.1                     v1.1
# 10   F9 v1.1 B1011                     v1.1
# 11   F9 v1.1 B1010                     v1.1
# 12   F9 v1.1 B1012                     v1.1
# 13   F9 v1.1 B1013                     v1.1
# 14   F9 v1.1 B1014                     v1.1
# 15   F9 v1.1 B1015                     v1.1
# 16   F9 v1.1 B1016                     v1.1
# 17   F9 v1.1 B1018                     v1.1
# 18     F9 FT B1019                       FT
# 19     F9 FT B1020                       FT
# 20   F9 FT B1021.1                       FT
# 21     F9 FT B1022                       FT
# 22   F9 FT B1023.1                       FT
# 23     F9 FT B1024                       FT
# 24   F9 FT B1025.1                       FT
# 25     F9 FT B1026                       FT
# 26  F9 v1.1  B1003                     v1.1
# 27   F9 v1.1 B1017                     v1.1
# 28   F9 FT B1029.1                       FT
# 29   F9 FT B1036.1                       FT
# 30   F9 FT B1038.1                       FT
# 31   F9 B4 B1041.1                       B4
# 32  F9 FT  B1036.2                       FT
# 33  F9 FT  B1038.2                       FT
# 34  F9 B4  B1041.2                       B4
# 35  F9 B4  B1043.2                       B4
# 36   F9 FT B1031.1                       FT
# 37     F9 FT B1030                       FT
# 38  F9 FT  B1021.2                       FT
# 39   F9 FT B1032.1                       FT
# 40     F9 FT B1034                       FT
# 41   F9 FT B1035.1                       FT
# 42  F9 FT  B1029.2                       FT
# 43     F9 FT B1037                       FT
# 44   F9 B4 B1039.1                       B4
# 45   F9 B4 B1040.1                       B4
# 46  F9 FT  B1031.2                       FT
# 47   F9 B4 B1042.1                       B4
# 48  F9 B5  B1046.1                       B5
# 49  F9 FT  B1035.2                       FT
# 50   F9 B4 B1043.1                       B4
# 51  F9 FT  B1032.2                       FT
# 52     F9 B4 B1044                       B4
# 53  F9 B4  B1039.2                       B4
# 54   F9 B4 B1045.1                       B4
# 55  F9 B4  B1040.2                       B4

# %%
df =  spacex_df[spacex_df['Launch Site']=='CCAFS LC-40']
#launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
new_df=df[['class','Flight Number']]
pie_data = new_df.groupby(['class'], as_index=False).count()
pie_data
# Out:
#    class  Flight Number
# 0      0             19
# 1      1              7

# %%
# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = dash.Dash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(id='site-dropdown',
                                options=[
                                    {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                    {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                    {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                    {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
                                    {'label': 'All Sites', 'value': 'ALL'},                                
                                ],
                                value = 'CCAFS LC-40',
                                placeholder = 'Select a Launch Site here',
                                searchable = True
                                ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                dcc.RangeSlider(id='payload-slider', min=0, max=10000, step=100, value=[spacex_df['Payload Mass (kg)'].min(), spacex_df['Payload Mass (kg)'].max()]),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback( Output(component_id='success-pie-chart', component_property='figure'),
               Input(component_id='site-dropdown', component_property='value'))

# Add computation to callback function and return graph
def get_graph(entered_site):
    
    # Select data for custom Launch Site
    if entered_site=='ALL':
        df =  spacex_df[spacex_df['class']==1] #making new df where only records with successfull starts are taken
        new_df=df[['class','Launch Site']]
        pie_data = new_df.groupby(['Launch Site'], as_index=False).count()
        fig = px.pie(pie_data, values=pie_data['class'], names=pie_data['Launch Site'], title='Successfull Launches Distributed by Launch Sites')
    else:
        df =  spacex_df[spacex_df['Launch Site']==entered_site]
        new_df=df[['class','Flight Number']]
        pie_data = new_df.groupby(['class'], as_index=False).count()
        fig = px.pie(pie_data, values=pie_data['Flight Number'], names=pie_data['class'], title='Success (1)/Failure (0) Launches for Site '+format(entered_site))
    return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback( Output(component_id='success-payload-scatter-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'),
              Input(component_id='payload-slider', component_property='value'))

def get_graph_slider(entered_site, slider_range):
    low, high = slider_range
    mask = (spacex_df['Payload Mass (kg)'] > low) & (spacex_df['Payload Mass (kg)'] < high)
    new_spacex_df=spacex_df[mask]
    
    if entered_site=='ALL':
        df = new_spacex_df
        fig = px.scatter(df, x=df['Payload Mass (kg)'], y=df['class'], color=df['Booster Version Category'])
    else:
        df =  new_spacex_df[spacex_df['Launch Site']==entered_site]
        fig = px.scatter(df, x=df['Payload Mass (kg)'], y=df['class'], color=df['Booster Version Category'])
    return fig 

# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [17/Aug/2021 02:07:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:44] "GET /_dash-component-suites/dash/deps/polyfill@7.v1_21_0m1629134259.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:44] "GET /_dash-component-suites/dash/deps/react@16.v1_21_0m1629134259.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:44] "GET /_dash-component-suites/dash/deps/prop-types@15.v1_21_0m1629134259.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:44] "GET /_dash-component-suites/dash/deps/react-dom@16.v1_21_0m1629134259.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:44] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_1_4m1629134259.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:44] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_17_1m1629134259.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:44] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v1_21_0m1629134259.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:44] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_17_1m1629134259.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:45] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:45] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:45] "GET /_favicon.ico?v=1.21.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:45] "GET /_dash-component-suites/dash_core_components/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:45] "GET /_dash-component-suites/dash_core_components/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:45] "GET /_dash-component-suites/dash_core_components/async-slider.js HTTP/1.1" 200 -
# <ipython-input-6-fa7da70c9e4d>:78: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df =  new_spacex_df[spacex_df['Launch Site']==entered_site]
# 127.0.0.1 - - [17/Aug/2021 02:07:45] "GET /_dash-component-suites/dash_core_components/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:07:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:08:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2021 02:08:12] "POST /_dash-update-component HTTP/1.1" 200 -
